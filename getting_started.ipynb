# %% [markdown]
# # Task 1
#
# ---
#
# ## Web scraping and analysis
#
# This Jupyter notebook includes some code to get you started with web scraping. We will use a package called `BeautifulSoup` to collect the data from the web. Once you've collected your data and saved it into a local `.csv` file you should start with your analysis.
#
# ### Scraping data from Skytrax
#
# If you visit [https://www.airlinequality.com] you can see that there is a lot of data there. For this task, we are only interested in reviews related to British Airways and the Airline itself.
#
# If you navigate to this link: [https://www.airlinequality.com/airline-reviews/british-airways] you will see this data. Now, we can use `Python` and `BeautifulSoup` to collect all the links to the reviews and then to collect the text data on each of the individual review links.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 100
page_size = 100

reviews = []

# for i in range(1, pages + 1):
for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
    
    print(f"   ---> {len(reviews)} total reviews")
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews
# Scraping page 11
#    ---> 1100 total reviews
# Scraping page 12
#    ---> 1200 total reviews
# Scraping page 13
#    ---> 1300 total reviews
# Scraping page 14
#    ---> 1400 total reviews
# Scraping page 15
#    ---> 1500 total reviews
# Scraping page 16
#    ---> 1600 total reviews
# Scraping page 17
#    ---> 1700 total reviews
# Scraping page 18
#    ---> 1800 total reviews
# Scraping page 19
#    ---> 1900 total reviews
# Scraping page 20
#    ---> 2000 total reviews
# Scraping page 21
#    ---> 2100 total reviews
# Scraping page 22
#    ---> 2200 total reviews
# Scraping page 23
#    ---> 2300 total reviews
# Scraping page 24
#    ---> 2400 total reviews
# Scraping page 25
#    ---> 2500 total reviews
# Scraping page 26
#    ---> 2600 total reviews
# Scraping page 27
#    ---> 2700 total reviews
# Scraping page 28
#    ---> 2800 total reviews
# Scraping page 29
#    ---> 2900 total reviews
# Scraping page 30
#    ---> 3000 total reviews
# Scraping page 31
#    ---> 3100 total reviews
# Scraping page 32
#    ---> 3200 total reviews
# Scraping page 33
#    ---> 3300 total reviews
# Scraping page 34
#    ---> 3400 total reviews
# Scraping page 35
#    ---> 3500 total reviews
# Scraping page 36
#    ---> 3600 total reviews
# Scraping page 37
#    ---> 3700 total reviews
# Scraping page 38
#    ---> 3702 total reviews
# Scraping page 39
#    ---> 3702 total reviews
# Scraping page 40
#    ---> 3702 total reviews
# Scraping page 41
#    ---> 3702 total reviews
# Scraping page 42
#    ---> 3702 total reviews
# Scraping page 43
#    ---> 3702 total reviews
# Scraping page 44
#    ---> 3702 total reviews
# Scraping page 45
#    ---> 3702 total reviews
# Scraping page 46
#    ---> 3702 total reviews
# Scraping page 47
#    ---> 3702 total reviews
# Scraping page 48
#    ---> 3702 total reviews
# Scraping page 49
#    ---> 3702 total reviews
# Scraping page 50
#    ---> 3702 total reviews
# Scraping page 51
#    ---> 3702 total reviews
# Scraping page 52
#    ---> 3702 total reviews
# Scraping page 53
#    ---> 3702 total reviews
# Scraping page 54
#    ---> 3702 total reviews
# Scraping page 55
#    ---> 3702 total reviews
# Scraping page 56
#    ---> 3702 total reviews
# Scraping page 57
#    ---> 3702 total reviews
# Scraping page 58
#    ---> 3702 total reviews
# Scraping page 59
#    ---> 3702 total reviews
# Scraping page 60
#    ---> 3702 total reviews
# Scraping page 61
#    ---> 3702 total reviews
# Scraping page 62
#    ---> 3702 total reviews
# Scraping page 63
#    ---> 3702 total reviews
# Scraping page 64
#    ---> 3702 total reviews
# Scraping page 65
#    ---> 3702 total reviews
# Scraping page 66
#    ---> 3702 total reviews
# Scraping page 67
#    ---> 3702 total reviews
# Scraping page 68
#    ---> 3702 total reviews
# Scraping page 69
#    ---> 3702 total reviews
# Scraping page 70
#    ---> 3702 total reviews
# Scraping page 71
#    ---> 3702 total reviews
# Scraping page 72
#    ---> 3702 total reviews
# Scraping page 73
#    ---> 3702 total reviews
# Scraping page 74
#    ---> 3702 total reviews
# Scraping page 75
#    ---> 3702 total reviews
# Scraping page 76
#    ---> 3702 total reviews
# Scraping page 77
#    ---> 3702 total reviews
# Scraping page 78
#    ---> 3702 total reviews
# Scraping page 79
#    ---> 3702 total reviews
# Scraping page 80
#    ---> 3702 total reviews
# Scraping page 81
#    ---> 3702 total reviews
# Scraping page 82
#    ---> 3702 total reviews
# Scraping page 83
#    ---> 3702 total reviews
# Scraping page 84
#    ---> 3702 total reviews
# Scraping page 85
#    ---> 3702 total reviews
# Scraping page 86
#    ---> 3702 total reviews
# Scraping page 87
#    ---> 3702 total reviews
# Scraping page 88
#    ---> 3702 total reviews
# Scraping page 89
#    ---> 3702 total reviews
# Scraping page 90
#    ---> 3702 total reviews
# Scraping page 91
#    ---> 3702 total reviews
# Scraping page 92
#    ---> 3702 total reviews
# Scraping page 93
#    ---> 3702 total reviews
# Scraping page 94
#    ---> 3702 total reviews
# Scraping page 95
#    ---> 3702 total reviews
# Scraping page 96
#    ---> 3702 total reviews
# Scraping page 97
#    ---> 3702 total reviews
# Scraping page 98
#    ---> 3702 total reviews
# Scraping page 99
#    ---> 3702 total reviews
# Scraping page 100
#    ---> 3702 total reviews

# %%
df = pd.DataFrame()
df["reviews"] = reviews
df.head()
# Out:
#                                              reviews
# 0  ✅ Trip Verified |  Quick bag drop at First Win...
# 1  ✅ Trip Verified |  4 Hours before takeoff we r...
# 2  ✅ Trip Verified |  I recently had a delay on B...
# 3  Not Verified |  Boarded on time, but it took a...
# 4  ✅ Trip Verified |  5 days before the flight, w...

# %%
df
# Out:
#                                                 reviews
# 0     ✅ Trip Verified |  Quick bag drop at First Win...
# 1     ✅ Trip Verified |  4 Hours before takeoff we r...
# 2     ✅ Trip Verified |  I recently had a delay on B...
# 3     Not Verified |  Boarded on time, but it took a...
# 4     ✅ Trip Verified |  5 days before the flight, w...
# ...                                                 ...
# 3697  LHR-JFK-LAX-LHR. Check in was ok apart from be...
# 3698  LHR to HAM. Purser addresses all club passenge...
# 3699  My son who had worked for British Airways urge...
# 3700  London City-New York JFK via Shannon on A318 b...
# 3701  SIN-LHR BA12 B747-436 First Class. Old aircraf...
#
# [3702 rows x 1 columns]

# %%
df.to_csv("BA_reviews.csv")

# %% [markdown]
# Congratulations! Now you have your dataset for this task! The loops above collected 1000 reviews by iterating through the paginated pages on the website. However, if you want to collect more data, try increasing the number of pages!
#
#  The next thing that you should do is clean this data to remove any unnecessary text from each of the rows. For example, "✅ Trip Verified" can be removed from each row if it exists, as it's not relevant to what we want to investigate.
